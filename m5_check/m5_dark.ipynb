# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import healpy as hp
from rubin_scheduler.skybrightness_pre import dark_sky
from rubin_scheduler.scheduler.model_observatory import ModelObservatory
from rubin_scheduler.scheduler.basis_functions import M5DiffBasisFunction

# %%
# branch
mo = ModelObservatory(nside=32)
conditions = mo.return_conditions()

for filtername in 'ugrizy':
    bf = M5DiffBasisFunction(nside=32, filtername=filtername)
    _temp = bf(conditions)
    hp.mollview(bf.dark_map, title=filtername)

# %%
# main
mo = ModelObservatory(nside=32)
conditions = mo.return_conditions()

for filtername in 'ugrizy':
    bf = M5DiffBasisFunction(nside=32, filtername=filtername)
    _temp = bf(conditions)
    hp.mollview(bf.dark_map, title=filtername)
