# %%
import numpy as np
from rubin_sim import skybrightness
import matplotlib.pylab as plt
# %matplotlib inline

# %%
sky_model = skybrightness.SkyModel()

ra, dec = 60.49055482066166, -38.16437996317624
mjd = 60143.421569611106

sky_model.set_ra_dec_mjd(ra, dec, mjd, degrees=True)
wave, spec = sky_model.return_wave_spec()

print(spec[0])
# Out:
# [           nan            nan            nan ... 1.16628121e-14
#  9.88205945e-15 7.54986504e-15]

# %%
plt.plot(wave, spec[0])

# %%
sky_model = skybrightness.SkyModel(mags=True)

ra, dec = 60.49055482066166, -38.16437996317624
mjd = 60143.421569611106

sky_model.set_ra_dec_mjd(ra, dec, mjd, degrees=True)
mags = sky_model.return_mags()

print(mags)
# Out:
# {'u': array([22.64005698]), 'g': array([22.1599917]), 'r': array([21.17938276]), 'i': array([20.26375837]), 'z': array([19.31013899]), 'y': array([18.41220049])}
